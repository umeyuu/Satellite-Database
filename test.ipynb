# %%
from src.charge import SAT_DATA
from src.preprocess import Process_Binary_File
from datetime import datetime
import pandas as pd

# %% [markdown]
# ### cdfファイルの情報を調べる

# %%
index = 16
year = 2011
month = '05'
day = '02'

path = f'/Volumes/USB/Raw_Data/dmsp-f{index}/{year}/{month}/dmsp-f{index}_{year}{month}{day}.cdf'
sat = SAT_DATA()
sat.open(path=path)
sat.heat_map(mode='I')
sat.heat_map(mode='E')
a = sat.ion

# %%
sat.plot_spectra()

# %%
sat.plot_charge_pos()

# %% [markdown]
# ### バイナリーファイルをcsvに変換して、情報を調べる

# %%
pbf = Process_Binary_File()
YMD = datetime(2011, 5, 2)
df = pbf.execute(YMD=YMD, index=16)
df.to_csv('test.csv', index=False)

# %%
path = f'test.csv'
sat = SAT_DATA()
sat.open(path=path)
sat.heat_map(mode='I')
sat.heat_map(mode='E')

# %%
sat.plot_spectra()

# %%
sat.plot_charge_pos()
